# %%
# Install NBA API
# !pip install nba_api
# Out:
# ...
#   Using cached nba_api-1.1.11-py3-none-any.whl
# ...

# %%
import pickle
file = open('../data/players_stats.pkl', 'rb')
x = pickle.load(file)
file.close()

# %%
len(x)
# Out:
# 4723

# %%
x[:3]
# Out:
# [{'id': 76001,
#   'info': <nba_api.stats.endpoints.commonplayerinfo.CommonPlayerInfo at 0xffff9a97b370>,
#   'career': <nba_api.stats.endpoints.playercareerstats.PlayerCareerStats at 0xffff6c7cafa0>},
#  {'id': 76002,
#   'info': <nba_api.stats.endpoints.commonplayerinfo.CommonPlayerInfo at 0xffff6c7de8e0>,
#   'career': <nba_api.stats.endpoints.playercareerstats.PlayerCareerStats at 0xffff6c7debb0>},
#  {'id': 76003,
#   'info': <nba_api.stats.endpoints.commonplayerinfo.CommonPlayerInfo at 0xffff6c7f74c0>,
#   'career': <nba_api.stats.endpoints.playercareerstats.PlayerCareerStats at 0xffff6c7f7790>}]

# %%
x[858]['info'].get_data_frames()[0]
# Out:
#    PERSON_ID FIRST_NAME  LAST_NAME DISPLAY_FIRST_LAST  \
# 0     203496     Robert  Covington   Robert Covington
#
#   DISPLAY_LAST_COMMA_FIRST DISPLAY_FI_LAST       PLAYER_SLUG  \
# 0        Covington, Robert    R. Covington  robert-covington
#
#              BIRTHDATE           SCHOOL COUNTRY  ...        PLAYERCODE  \
# 0  1990-12-14T00:00:00  Tennessee State     USA  ...  robert_covington
#
#   FROM_YEAR TO_YEAR  DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR  \
# 0      2013    2021             Y        Y                 Y  Undrafted
#
#   DRAFT_ROUND  DRAFT_NUMBER GREATEST_75_FLAG
# 0   Undrafted     Undrafted                N
#
# [1 rows x 33 columns]

# %%
x[858]['career'].get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203496   2013-14        00  1610612745               HOU        23.0
# 1      203496   2014-15        00  1610612755               PHI        24.0
# 2      203496   2015-16        00  1610612755               PHI        25.0
# 3      203496   2016-17        00  1610612755               PHI        26.0
# 4      203496   2017-18        00  1610612755               PHI        27.0
# 5      203496   2018-19        00  1610612755               PHI        28.0
# 6      203496   2018-19        00  1610612750               MIN        28.0
# 7      203496   2018-19        00           0               TOT        28.0
# 8      203496   2019-20        00  1610612750               MIN        29.0
# 9      203496   2019-20        00  1610612745               HOU        29.0
# 10     203496   2019-20        00           0               TOT        29.0
# ...

# %%
[player for player in x if player['id'] == 203076][0]['info'].get_data_frames()[0]
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     203076    Anthony     Davis      Anthony Davis           Davis, Anthony
#
#   DISPLAY_FI_LAST    PLAYER_SLUG            BIRTHDATE    SCHOOL COUNTRY  ...  \
# 0        A. Davis  anthony-davis  1993-03-11T00:00:00  Kentucky     USA  ...
#
#       PLAYERCODE FROM_YEAR TO_YEAR  DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG  \
# 0  anthony_davis      2012    2021             N        Y                 Y
#
#   DRAFT_YEAR DRAFT_ROUND  DRAFT_NUMBER GREATEST_75_FLAG
# 0       2012           1             1                Y
#
# [1 rows x 33 columns]

# %%
# [player for player in x]

# %%
[player for player in x if player['id'] == 203076][0]['career'].get_available_data()
# Out:
# dict_keys(['SeasonTotalsRegularSeason', 'CareerTotalsRegularSeason', 'SeasonTotalsPostSeason', 'CareerTotalsPostSeason', 'SeasonTotalsAllStarSeason', 'CareerTotalsAllStarSeason', 'SeasonTotalsCollegeSeason', 'CareerTotalsCollegeSeason', 'SeasonTotalsShowcaseSeason', 'CareerTotalsShowcaseSeason', 'SeasonRankingsRegularSeason', 'SeasonRankingsPostSeason'])

# %%
[player for player in x if player['id'] == 203076][0]['career'].season_totals_all_star_season.get_data_frame()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2013-14        00  1610616834               WST        21.0
# 1     203076   2015-16        00  1610616834               WST        23.0
# 2     203076   2016-17        00  1610616834               WST        24.0
# 3     203076   2017-18        00  1610616833               LBN        25.0
# 4     203076   2018-19        00  1610616834               LBN        26.0
# 5     203076   2019-20        00  1610616834               LBN        27.0
#
#    GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0   1   0  10.0    5  ...     0.0     0     1    1    0    2    0    1   0
# 1   1   0  15.0   12  ...     0.0     3     3    6    0    1    0    0   1
# 2   1   1  32.0   26  ...     0.0     4     6   10    0    2    0    1   1
# 3   1   1  17.0    6  ...     0.0     1     1    2    1    0    0    1   2
# ...

# %%
[player for player in x if player['id'] == 203076][0]['career'].get_data_frames()[4]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2013-14        00  1610616834               WST        21.0
# 1     203076   2015-16        00  1610616834               WST        23.0
# 2     203076   2016-17        00  1610616834               WST        24.0
# 3     203076   2017-18        00  1610616833               LBN        25.0
# 4     203076   2018-19        00  1610616834               LBN        26.0
# 5     203076   2019-20        00  1610616834               LBN        27.0
#
#    GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0   1   0  10.0    5  ...     0.0     0     1    1    0    2    0    1   0
# 1   1   0  15.0   12  ...     0.0     3     3    6    0    1    0    0   1
# 2   1   1  32.0   26  ...     0.0     4     6   10    0    2    0    1   1
# 3   1   1  17.0    6  ...     0.0     1     1    2    1    0    0    1   2
# ...

# %%
[player for player in x if player['id'] == 203076][0]['career'].season_totals_regular_season.get_data_frame()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
# 8     203076   2020-21        00  1610612747               LAL        28.0
# 9     203076   2021-22        00  1610612747               LAL        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# ...

# %%
[player for player in x if player['id'] == 203076][0]['career'].season_totals_regular_season.get_json()
# Out:
# '{"headers": ["PLAYER_ID", "SEASON_ID", "LEAGUE_ID", "TEAM_ID", "TEAM_ABBREVIATION", "PLAYER_AGE", "GP", "GS", "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", "BLK", "TOV", "PF", "PTS"], "data": [[203076, "2012-13", "00", 1610612740, "NOH", 20.0, 64, 60, 1846.0, 349, 676, 0.516, 0, 6, 0.0, 169, 225, 0.751, 165, 357, 522, 63, 75, 112, 89, 158, 867], [203076, "2013-14", "00", 1610612740, "NOP", 21.0, 67, 66, 2358.0, 522, 1005, 0.519, 2, 9, 0.222, 348, 440, 0.791, 207, 466, 673, 105, 89, 189, 109, 200, 1394], [203076, "2014-15", "00", 1610612740, "NOP", 22.0, 68, 68, 2455.0, 642, 1199, 0.535, 1, 12, 0.083, 371, 461, 0.805, 173, 523, 696, 149, 100, 200, 95, 141, 1656], [203076, "2015-16", "00", 1610612740, "NOP", 23.0, 61, 61, 2164.0, 560, 1136, 0.493, 35, 108, 0.324, 326, 430, 0.758, 130, 497, 627, 116, 78, 125, 121, 148, 1481], [203076, "2016-17", "00", 1610612740, "NOP", 24.0, 75, 75, 2708.0, 770, 1526, 0.505, 40, 
# ...
